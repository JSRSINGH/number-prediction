# %%
# =============================================================
# STEP 1: Install Dependencies (run this only once)
# =============================================================
# !pip install opencv-python-headless matplotlib tensorflow tqdm

# =============================================================
# STEP 2: Import Libraries
# =============================================================
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
import numpy as np
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
from IPython.display import Video, display
import os

print("TensorFlow version:", tf.__version__)

# =============================================================
# STEP 3: Load and Preprocess MNIST Data
# =============================================================
(train_images, train_labels), (test_images, test_labels) = keras.datasets.mnist.load_data()

# reshape and normalize
train_images = train_images.reshape(train_images.shape[0], 28, 28, 1).astype("float32") / 255.0
test_images = test_images.reshape(test_images.shape[0], 28, 28, 1).astype("float32") / 255.0

# =============================================================
# STEP 4: Build CNN Model
# =============================================================
model = keras.Sequential([
    keras.Input(shape=(28, 28, 1)),
    Conv2D(32, (3, 3), activation='relu'),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# =============================================================
# STEP 5: Train the Model
# =============================================================
print("🧠 Training model (takes about 2–3 minutes)...")
model.fit(train_images, train_labels, epochs=3, batch_size=128, verbose=1)

# Evaluate quickly
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"✅ Test Accuracy: {test_acc:.4f}")

# =============================================================
# STEP 6: Helper Function to Preprocess Each Video Frame
# =============================================================
def preprocess_frame(frame):
    """Convert video frame to normalized 28x28 grayscale for prediction."""
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    gray = cv2.resize(gray, (28, 28))
    gray = 1 - (gray / 255.0)  # invert colors (white digit on black background)
    gray = np.expand_dims(gray, axis=(0, -1))  # shape (1, 28, 28, 1)
    return gray

# =============================================================
# STEP 7: Load Your MNIST Dream Video
# =============================================================
video_path = "mnist_dream.mp4"  # Make sure your file is named like this
if not os.path.exists(video_path):
    raise FileNotFoundError(f"❌ File '{video_path}' not found. Please upload it here.")

cap = cv2.VideoCapture(video_path)
frame_total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(f"🎥 Processing {frame_total} frames...")

# =============================================================
# STEP 8: Predict and Save Annotated Output Video
# =============================================================
output_path = "mnist_predicted.mp4"
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
vw = None

for _ in tqdm(range(frame_total), desc="Processing Frames"):
    ret, frame = cap.read()
    if not ret:
        break

    # preprocess and predict
    x = preprocess_frame(frame)
    preds = model.predict(x, verbose=0)[0]
    guess = np.argmax(preds)
    conf = np.max(preds) * 100

    # resize for display
    disp_frame = cv2.resize(frame, (640, 640))

    # ========= TEXT VISIBILITY FIX =========
    text = f"Prediction: {guess} ({conf:.1f}%)"
    # black outline
    cv2.putText(disp_frame, text, (20, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.2, (0, 0, 0), 5)
    # white text on top
    cv2.putText(disp_frame, text, (20, 50), cv2.FONT_HERSHEY_SIMPLEX, 1.2, (255, 255, 255), 2)

    # initialize writer
    if vw is None:
        h, w, _ = disp_frame.shape
        vw = cv2.VideoWriter(output_path, fourcc, 30.0, (w, h))

    vw.write(disp_frame)

cap.release()
if vw:
    vw.release()

print(f"\n✅ Done! Saved output video as '{output_path}'")

# =============================================================
# STEP 9: Display the Output Video Inside Notebook
# =============================================================
display(Video(output_path, embed=True))
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python-headless in c:\users\siddharth\appdata\roaming\python\python313\site-packages (4.12.0.88)
# Requirement already satisfied: matplotlib in c:\users\siddharth\appdata\roaming\python\python313\site-packages (3.10.6)
# Requirement already satisfied: tensorflow in c:\users\siddharth\appdata\roaming\python\python313\site-packages (2.20.0)
# Requirement already satisfied: tqdm in c:\users\siddharth\appdata\roaming\python\python313\site-packages (4.67.1)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from opencv-python-headless) (2.2.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (6.32.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (1.75.1)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorboard~=2.20.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: colorama in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from keras>=3.10.0->tensorflow) (14.1.0)
# Requirement already satisfied: namex in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\siddharth\appdata\roaming\python\python313\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# TensorFlow version: 2.20.0
# 🧠 Training model (takes about 2–3 minutes)...
# Epoch 1/3
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 62s 125ms/step - accuracy: 0.9260 - loss: 0.2434
# Epoch 2/3
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 83s 128ms/step - accuracy: 0.9755 - loss: 0.0811
# Epoch 3/3
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 60s 127ms/step - accuracy: 0.9804 - loss: 0.0648
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9874 - loss: 0.0366
# ✅ Test Accuracy: 0.9874
# 🎥 Processing 481 frames...
# Processing Frames: 100%|█████████████████████████████████████████████████████████████| 481/481 [01:22<00:00,  5.80it/s]
# ✅ Done! Saved output video as 'mnist_predicted.mp4'
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
